# %% [markdown]
# # Caso de estudio. Movielens

# %%
# !dir
# !dir movielens
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: 3C30-AE92
#
#  Directorio de C:\Users\Max Dacko\Documents\Carpeta Prueba
#
# 14/06/2021  05:26 p. m.    <DIR>          .
# 14/06/2021  05:26 p. m.    <DIR>          ..
# 14/06/2021  04:24 p. m.    <DIR>          .ipynb_checkpoints
# 09/06/2021  05:33 p. m.            19.907 Color.ipynb
# 14/06/2021  04:29 p. m.    <DIR>          movielens
# 14/06/2021  05:26 p. m.           178.702 movielens.ipynb
# 14/06/2021  12:45 p. m.            40.024 numpy.ipynb
# 14/06/2021  10:58 a. m.             1.708 numpyMio.ipynb
# 14/06/2021  04:21 p. m.            42.069 pandas.ipynb
# 14/06/2021  01:22 p. m.         3.398.804 procesndoImagenes.ipynb
# 09/06/2021  05:19 p. m.            18.315 Prueba.ipynb
#                7 archivos      3.699.529 bytes
#                4 dirs  408.377.384.960 bytes libres
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: 3C30-AE92
#
#  Directorio de C:\Users\Max Dacko\Documents\Carpeta Prueba\movielens
#
# 14/06/2021  04:29 p. m.    <DIR>          .
# 14/06/2021  04:29 p. m.    <DIR>          ..
# 03/06/2019  12:49 p. m.       323.544.381 genome-scores.csv
# 03/06/2019  12:35 p. m.            18.103 genome-tags.csv
# 03/06/2019  12:35 p. m.                 0 Icon_
# 03/06/2019  12:35 p. m.           570.090 links.csv
# 03/06/2019  12:49 p. m.         1.397.542 movies.csv
# 03/06/2019  12:43 p. m.       533.444.411 ratings.csv
# 03/06/2019  12:35 p. m.            10.261 README.txt
# 03/06/2019  12:35 p. m.        16.603.996 tags.csv
#                8 archivos    875.588.784 bytes
#                2 dirs  408.377.384.960 bytes libres

# %%
import pandas as pd
movies = pd.read_csv('movielens/movies.csv', sep=',')
tags = pd.read_csv('movielens/tags.csv', sep=',')
ratings = pd.read_csv('movielens/ratings.csv', sep=',')

movies.head(15)
# Out:
#     movieId                               title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
# 5         6                         Heat (1995)
# 6         7                      Sabrina (1995)
# 7         8                 Tom and Huck (1995)
# 8         9                 Sudden Death (1995)
# 9        10                    GoldenEye (1995)
# 10       11      American President, The (1995)
# 11       12  Dracula: Dead and Loving It (1995)
# 12       13                        Balto (1995)
# 13       14                        Nixon (1995)
# 14       15             Cutthroat Island (1995)
#
#                                          genres
# 0   Adventure|Animation|Children|Comedy|Fantasy
# 1                    Adventure|Children|Fantasy
# 2                                Comedy|Romance
# 3                          Comedy|Drama|Romance
# 4                                        Comedy
# 5                         Action|Crime|Thriller
# 6                                Comedy|Romance
# 7                            Adventure|Children
# 8                                        Action
# 9                     Action|Adventure|Thriller
# 10                         Comedy|Drama|Romance
# 11                                Comedy|Horror
# 12                 Adventure|Animation|Children
# 13                                        Drama
# 14                     Action|Adventure|Romance

# %%
tags.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %%
ratings.tail(10)
# Out:
#           userId  movieId  rating   timestamp
# 20000253  138493    60816     4.5  1259865163
# 20000254  138493    61160     4.0  1258390537
# 20000255  138493    65682     4.5  1255816373
# 20000256  138493    66762     4.5  1255805408
# 20000257  138493    68319     4.5  1260209720
# 20000258  138493    68954     4.5  1258126920
# 20000259  138493    69526     4.5  1259865108
# 20000260  138493    69644     3.0  1260209457
# 20000261  138493    70286     5.0  1258126944
# 20000262  138493    71619     2.5  1255811136

# %%
# de momento borraremos las columnas timestamp en tags y ratings
del ratings['timestamp']
del tags['timestamp']

# %%
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %% [markdown]
# <br><br><br><h1 style="font-size:1.5em;color:#2467C0">Operamos con Series </h1>

# %%
# Extraemos una fila y confirmamos que de hecho es una serie
row_0 = tags.iloc[0]
type(row_0)
# Out:
# pandas.core.series.Series

# %%
print(row_0)
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
row_0.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
row_0['userId']
# Out:
# 18

# %%
'rating' in row_0
# Out:
# False

# %% [markdown]
# <br><br><br> <h1 style="font-size:1.5em;color:#2467C0">Operamos con DataFrames </h1>

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
ratings['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
# extraemos a la fila 0 21 y 2005
tags.iloc[ [0,21,2005] ]
# Out:
#       userId  movieId          tag
# 0         18     4141  Mark Waters
# 21        65     6874    dark hero
# 2005     910    97938     stranded

# %% [markdown]
# <h1 style="font-size:2em;color:#2467C0">Analizamos la estadística básica del conjunto</h1>

# %%
ratings['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings.describe()
# Out:
#              userId       movieId        rating     timestamp
# count  2.000026e+07  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00  1.100918e+09
# std    4.003863e+04  1.978948e+04  1.051989e+00  1.621694e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
# 25%    3.439500e+04  9.020000e+02  3.000000e+00  9.667977e+08
# 50%    6.914100e+04  2.167000e+03  3.500000e+00  1.103556e+09
# 75%    1.036370e+05  4.770000e+03  4.000000e+00  1.225642e+09
# max    1.384930e+05  1.312620e+05  5.000000e+00  1.427784e+09

# %%
ratings['rating'].mean()
# Out:
# 3.5255285642993797

# %%
ratings.mean()
# Out:
# userId       6.904587e+04
# movieId      9.041567e+03
# rating       3.525529e+00
# timestamp    1.100918e+09
# dtype: float64

# %%
ratings['rating'].min()
# Out:
# 0.5

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
ratings['rating'].std()
# Out:
# 1.051988919275684

# %%
ratings['rating'].mode()
# Out:
# 0    4.0
# dtype: float64

# %%
# este método nos permite observar una posible correlación de una columna con respecto a las otras
# una correlación negativa nos indicaría una correlación inversa.
# una correlación positiva nos indicaría una correlación directa.
# ¿realmente puede existir alguna correlación entre esta columnas (features)?
#ratings['testing'] = ratings['rating'] *  0.0000000000001
ratings.corr()
# Out:
#              userId   movieId    rating  timestamp
# userId     1.000000 -0.000850  0.001175  -0.003101
# movieId   -0.000850  1.000000  0.002606   0.459096
# rating     0.001175  0.002606  1.000000  -0.000512
# timestamp -0.003101  0.459096 -0.000512   1.000000

# %%
# estas líneas no solo están aquí para que practiquemos, 
# ya estamos explorando y analizando nuestro dataset, tarea fundamental, que tendremos
# que hacer antes de alimentar nuestro sistema de machine learning.
# ¿qué piensan que estamos buscando con estas líneas?
filter_1 = ratings['rating'] > 5
print(filter_1)
filter_1.any()
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# 5           False
# 6           False
# 7           False
# 8           False
# 9           False
# 10          False
# 11          False
# 12          False
# 13          False
# 14          False
# 15          False
# 16          False
# 17          False
# 18          False
# 19          False
# 20          False
# 21          False
# 22          False
# 23          False
# 24          False
# 25          False
# 26          False
# 27          False
# 28          False
# 29          False
#             ...
# 20000233    False
# 20000234    False
# 20000235    False
# 20000236    False
# 20000237    False
# 20000238    False
# 20000239    False
# 20000240    False
# 20000241    False
# 20000242    False
# 20000243    False
# 20000244    False
# 20000245    False
# 20000246    False
# 20000247    False
# 20000248    False
# 20000249    False
# 20000250    False
# 20000251    False
# 20000252    False
# 20000253    False
# 20000254    False
# 20000255    False
# 20000256    False
# 20000257    False
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261    False
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool
# False

# %% [markdown]
# EXACTO! Buscamos alguna falla en nuestro dataset, sabemos que la puntuación máxima es 5.
# Las líneas anteriores, tienen total coherencia, porque lo que estamos haciendo es buscar, si hay algún valor erróneo con un rating superior a 5

# %% [markdown]
# <br><br><br><h1 style="font-size:2em;color:#2467C0">Llegó la hora... <br><br> <b> Data cleaning</b></h1>

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# busquemos valores nulos
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %% [markdown]
# EXITO! No tenemos nulos en movies

# %%
ratings.isnull().any()
# Out:
# userId       False
# movieId      False
# rating       False
# timestamp    False
# dtype: bool

# %%
tags.isnull().any()
# Out:
# userId       False
# movieId      False
# tag           True
# timestamp    False
# dtype: bool

# %%
# ups, en la columna tag de tags hay columnas null
# controlamos la forma de tags
count = tags.shape[0]
print("La cantidad de filas antes de borrar es: ", count)
# Out:
# La cantidad de filas antes de borrar es:  465564

# %%
# borramos las filas que contengan algún valor nulo
tags = tags.dropna()
print("Se eliminaron ➢ ", count - tags.shape[0], " filas")
# Out:
# Se eliminaron ➢  16  filas

# %%
# comprovamos nuevamente
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag        False
# dtype: bool

# %% [markdown]
# <br><br><br><h1 style="font-size:2em;color:#2467C0">Con Pandas... <br><br> <b> graficar se hace Fácil</b></h1>

# %%
import matplotlib.pyplot as plt

# para usar fondo oscuro
plt.style.use("seaborn-dark")
# https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html

# ¿cuantos? y ¿dónde?
# frecuencia en el eje Y
ratings.hist(bins = 10, column='rating', figsize=(5,5))
# Out:
# array([[<AxesSubplot:title={'center':'rating'}>]], dtype=object)

# %%
# probabilidad de encontrar valor en ese bin
ratings.hist(bins = 10, column='rating', figsize=(5,5), normed = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-a2032b92a265> in <module>
#       1 # probabilidad de encontrar valor en ese bin
# ----> 2 ratings.hist(bins = 10, column='rating', figsize=(5,5), normed = True)
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     209     """
#     210     plot_backend = _get_plot_backend(backend)
# --> 211     return plot_backend.hist_frame(
#     212         data,
#     213         column=column,
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     446         if legend and can_set_label:
#     447             kwds["label"] = col
# --> 448         ax.hist(data[col].dropna().values, bins=bins, **kwds)
#     449         ax.set_title(col)
#     450         ax.grid(grid)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6813             if patch:
#    6814                 p = patch[0]
# -> 6815                 p.update(kwargs)
#    6816                 if lbl is not None:
#    6817                     p.set_label(lbl)
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
ratings.hist(bins = 10, column='rating', figsize=(5,5),  histtype="step", color="red")
# Out:
# array([[<AxesSubplot:title={'center':'rating'}>]], dtype=object)

# %%
#boxplot
ratings.boxplot(column='rating', figsize=(5,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/25/Boxplot.svg/457px-Boxplot.svg.png" style="background:white">

# %% [markdown]
# <br><br><br><h1 style="font-size:2em;color:#2467C0">Seleccionando Columnas</h1>

# %%
tags.head(15)
# Out:
#     userId  movieId                tag   timestamp
# 0       18     4141        Mark Waters  1240597180
# 1       65      208          dark hero  1368150078
# 2       65      353          dark hero  1368150079
# 3       65      521      noir thriller  1368149983
# 4       65      592          dark hero  1368150078
# 5       65      668          bollywood  1368149876
# 6       65      898   screwball comedy  1368150160
# 7       65     1248      noir thriller  1368149983
# 8       65     1391               mars  1368150055
# 9       65     1617           neo-noir  1368150217
# 10      65     1694              jesus  1368149925
# 11      65     1783      noir thriller  1368149983
# 12      65     2022              jesus  1368149925
# 13      65     2193             dragon  1368151314
# 14      65     2353  conspiracy theory  1368151266

# %%
movies[['title','genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
#una manera fácil de ir a las 10 últimas filas
ratings[-10:]
# Out:
#           userId  movieId  rating
# 20000253  138493    60816     4.5
# 20000254  138493    61160     4.0
# 20000255  138493    65682     4.5
# 20000256  138493    66762     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5

# %%
#otra manera fácil de acceder a la cola de una tabla
ratings.tail(10)
# Out:
#           userId  movieId  rating   timestamp
# 20000253  138493    60816     4.5  1259865163
# 20000254  138493    61160     4.0  1258390537
# 20000255  138493    65682     4.5  1255816373
# 20000256  138493    66762     4.5  1255805408
# 20000257  138493    68319     4.5  1260209720
# 20000258  138493    68954     4.5  1258126920
# 20000259  138493    69526     4.5  1259865108
# 20000260  138493    69644     3.0  1260209457
# 20000261  138493    70286     5.0  1258126944
# 20000262  138493    71619     2.5  1255811136

# %%
tag_counts = tags['tag'].value_counts()
tag_counts.head(100)
# Out:
# sci-fi             3384
# based on a book    3281
# atmospheric        2917
# comedy             2779
# action             2657
#                    ...
# inspirational       641
# stupid              639
# mystery             636
# family              612
# robots              602
# Name: tag, Length: 100, dtype: int64

# %%
tag_counts[:10].plot(kind='bar', figsize=(7,7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <br><br><br><h1 style="font-size:2em;color:#2467C0">Seleccionando / Filtrando Filas</h1>

# %%
filtro_mejores = ratings['rating'] >= 4.0
ratings[filtro_mejores][30:50]
# Out:
#      userId  movieId  rating   timestamp
# 68        1     2021     4.0  1112485929
# 69        1     2100     4.0  1112485955
# 70        1     2118     4.0  1094786092
# 71        1     2138     4.0  1112485789
# 72        1     2140     4.0  1112485705
# 73        1     2143     4.0  1112485951
# 74        1     2173     4.0  1112485887
# 75        1     2174     4.0  1112485843
# 76        1     2193     4.0  1112485753
# 79        1     2288     4.0  1094786077
# 80        1     2291     4.0  1094785777
# 81        1     2542     4.0  1112485447
# 82        1     2628     4.0  1112485988
# 90        1     2762     4.0  1112485367
# 92        1     2872     4.0  1112485697
# 94        1     2944     4.0  1112485433
# 96        1     2959     4.0  1094785698
# 97        1     2968     4.0  1112485825
# 101       1     3081     4.0  1094786143
# 102       1     3153     4.0  1112485816

# %%
filtro_animados = movies['genres'].str.contains('Animation')
animados = movies[filtro_animados]
animados.head()
# Out:
#      movieId                    title  \
# 0          1         Toy Story (1995)
# 12        13             Balto (1995)
# 47        48        Pocahontas (1995)
# 236      239    Goofy Movie, A (1995)
# 241      244  Gumby: The Movie (1995)
#
#                                           genres
# 0    Adventure|Animation|Children|Comedy|Fantasy
# 12                  Adventure|Animation|Children
# 47      Animation|Children|Drama|Musical|Romance
# 236            Animation|Children|Comedy|Romance
# 241                           Animation|Children

# %% [markdown]
# <br><br><br><h1 style="font-size:2em;color:#2467C0">Agrupar por y agregar</h1>

# %%
ratings_count = ratings[['movieId','rating']].groupby('rating').count()
ratings_count
#ratings.shape
# Out:
#         movieId
# rating
# 0.5      239125
# 1.0      680732
# 1.5      279252
# 2.0     1430997
# 2.5      883398
# 3.0     4291193
# 3.5     2200156
# 4.0     5561926
# 4.5     1534824
# 5.0     2898660

# %%
average_rating = ratings[['movieId','rating']].groupby('movieId').mean()
average_rating.head()
# Out:
#            rating
# movieId
# 1        3.921240
# 2        3.211977
# 3        3.151040
# 4        2.861393
# 5        3.064592

# %% [markdown]
# <br><br><br><h1 style="font-size:2em;color:#2467C0">Unir</h1>

# %%
tags.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
full = movies.merge(tags, on='movieId', how='inner')
print(full.shape)
inner_c = full.shape[0]

full = movies.merge(tags, on='movieId', how='left')
print(full.shape)
left_c = full.shape[0]

print("diferencia ->", left_c - inner_c)
# Out:
# (465564, 6)
# (473297, 6)
# diferencia -> 7733

# %% [markdown]
# Más ejemplos en: http://pandas.pydata.org/pandas-docs/stable/merging.html
#
# <img src="http://www.datasciencemadesimple.com/wp-content/uploads/2017/09/join-or-merge-in-python-pandas-1.png">

# %% [markdown]
# <br><br>
#
#
# ## Unimos, agregamos y aplicamos filtros

# %%
# calculamos los ratings promedios, agrupados por película

avg_ratings = ratings.groupby('movieId').mean()
del avg_ratings['userId']
del avg_ratings['timestamp']
avg_ratings.head()
# Out:
#            rating
# movieId
# 1        3.921240
# 2        3.211977
# 3        3.151040
# 4        2.861393
# 5        3.064592

# %%
# unimos los promedios, a donde sólo tenemos el id de la película, con el DF movies,
taquilla = movies.merge(avg_ratings, on='movieId', how='inner')
taquilla.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres    rating
# 0  Adventure|Animation|Children|Comedy|Fantasy  3.921240
# 1                   Adventure|Children|Fantasy  3.211977
# 2                               Comedy|Romance  3.151040
# 3                         Comedy|Drama|Romance  2.861393
# 4                                       Comedy  3.064592

# %%
las_mejores_filtro = taquilla['rating'] >= 5.0
las_mejores = taquilla[las_mejores_filtro]
las_mejores.head(50)
# Out:
#        movieId                                              title  \
# 9005     26718      Life On A String (Bian chang Bian Zou) (1991)
# 9557     27914  Hijacking Catastrophe: 9/11, Fear & the Sellin...
# 9857     32230            Snow Queen, The (Lumikuningatar) (1986)
# 10558    40404                                Al otro lado (2004)
# 12005    54326                                  Sierra, La (2005)
# 14406    72235     Between the Devil and the Deep Blue Sea (1995)
# 15687    79866            Schmatta: Rags to Riches to Rags (2009)
# 15994    81117                             Moth, The (Cma) (1980)
# 16952    86055        Foster Brothers, The (Süt kardesler) (1976)
# 17556    88488                Summer Wishes, Winter Dreams (1973)
# 17703    89133                               Boys (Drenge) (1977)
# 18597    92783                             Latin Music USA (2009)
# 18629    92956                            Little Criminals (1995)
# 18776    93707             Prom Queen: The Marc Hall Story (2004)
# 18841    93967  Keeping the Promise (Sign of the Beaver, The) ...
# 18934    94431                      Ella Lola, a la Trilby (1898)
# 18964    94657                    Turkish Dance, Ella Lola (1898)
# 18980    94737                       Boys Diving, Honolulu (1901)
# 19031    94949                               Boy Meets Boy (2008)
# 19040    94972                 Best of Ernie and Bert, The (1988)
# 19152    95517                  Barchester Chronicles, The (1982)
# 19258    95977                                 Junior Prom (1946)
# 19259    95979                                     Oranges (2004)
# 19971    98761  Shaolin Temple 2: Kids from Shaolin (Shao Lin ...
# 20085    99243                              Parasites, Les (1999)
# 20140    99450                                  Sun Kissed (2012)
# 20464   100521                    Who Killed Vincent Chin? (1987)
# 20511   100743                  Eye In The Sky (Gun chung) (2007)
# 20516   100830                  Blue Swallow (Cheong yeon) (2005)
# 20577   101188                                Central Park (1991)
# 20606   101292                                   Abendland (2011)
# 21005   102882                                 Dream Demon (1988)
# 21088   103143                           Donos de Portugal (2012)
# 21270   103753             Human Behavior Experiments, The (2006)
# 21310   103871  Consuming Kids: The Commercialization of Child...
# 21312   103875                     Iran Is Not the Problem (2008)
# 21318   103912                                    Giorgino (1994)
# 21415   104317    Flight of the Conchords: A Texan Odyssey (2006)
# 21656   105187                          Linotype: The Film (2012)
# 21658   105191                                Rocaterrania (2009)
# 21762   105526     Year Zero: The Silent Death of Cambodia (1979)
# 21763   105529                           Stealing a Nation (2004)
# 21840   105841                                      B-Side (2013)
# 21842   105846                               Only Daughter (2013)
# 21904   106076        Precision: The Measure of All Things (2013)
# 21906   106082     Shock and Awe: The Story of Electricity (2011)
# 21916   106113                      Such Hawks Such Hounds (2008)
# 21917   106115                       Story of Science, The (2010)
# 22027   106517                     De la servitude moderne (2009)
# 22215   107252                               Island at War (2004)
#
#                                 genres  rating
# 9005   Adventure|Drama|Fantasy|Musical     5.0
# 9557                       Documentary     5.0
# 9857                  Children|Fantasy     5.0
# 10558                            Drama     5.0
# 12005                      Documentary     5.0
# 14406                            Drama     5.0
# 15687                      Documentary     5.0
# 15994                            Drama     5.0
# 16952                           Comedy     5.0
# 17556                            Drama     5.0
# 17703                            Drama     5.0
# 18597              Documentary|Musical     5.0
# 18629                      Crime|Drama     5.0
# 18776                     Comedy|Drama     5.0
# 18841                   Children|Drama     5.0
# 18934               (no genres listed)     5.0
# 18964               (no genres listed)     5.0
# 18980                      Documentary     5.0
# 19031                          Romance     5.0
# 19040                         Children     5.0
# 19152                            Drama     5.0
# 19258                      Documentary     5.0
# 19259                            Drama     5.0
# 19971                    Action|Comedy     5.0
# 20085                           Comedy     5.0
# 20140                      Documentary     5.0
# 20464                Crime|Documentary     5.0
# 20511                   Crime|Thriller     5.0
# 20516                    Drama|Romance     5.0
# 20577                      Documentary     5.0
# 20606                      Documentary     5.0
# 21005                           Horror     5.0
# 21088                      Documentary     5.0
# 21270                      Documentary     5.0
# 21310                      Documentary     5.0
# 21312                      Documentary     5.0
# 21318           Adventure|Drama|Horror     5.0
# 21415                           Comedy     5.0
# 21656                      Documentary     5.0
# 21658              Documentary|Fantasy     5.0
# 21762                      Documentary     5.0
# 21763                      Documentary     5.0
# 21840                   Comedy|Romance     5.0
# 21842                            Drama     5.0
# 21904                      Documentary     5.0
# 21906                      Documentary     5.0
# 21916                      Documentary     5.0
# 21917                      Documentary     5.0
# 22027                      Documentary     5.0
# 22215                        Drama|War     5.0

# %%
## como los géneros en el DF están compuestos por múltiples palabras separados por | 
# es conveniente, hacer búsqueda de "si contiene" tal o cual palabra

comedias = taquilla['genres'].str.contains('Comedy')
taquilla[comedias].head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 6        7                      Sabrina (1995)
#
#                                         genres    rating
# 0  Adventure|Animation|Children|Comedy|Fantasy  3.921240
# 2                               Comedy|Romance  3.151040
# 3                         Comedy|Drama|Romance  2.861393
# 4                                       Comedy  3.064592
# 6                               Comedy|Romance  3.366484

# %% [markdown]
# <br><br><br><h1 style="font-size:2em;color:#2467C0">Operaciones con Strings</h1>

# %% [markdown]
# Partimos el género en cada uno de ellos. Nos valdremos del separador "  |  "

# %%
# analizar efecto de expand True / False
generos = movies['genres'].str.split('|', expand=True)
generos.head()
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
#
#       9
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
# a este tipo de columna se la suele llamar "flag"
generos['es_comedia'] = movies['genres'].str.contains('Comedy')

# %%
generos.head(100)
# Out:
#               0          1         2         3         4     5     6     7  \
# 0     Adventure  Animation  Children    Comedy   Fantasy  None  None  None
# 1     Adventure   Children   Fantasy      None      None  None  None  None
# 2        Comedy    Romance      None      None      None  None  None  None
# 3        Comedy      Drama   Romance      None      None  None  None  None
# 4        Comedy       None      None      None      None  None  None  None
# 5        Action      Crime  Thriller      None      None  None  None  None
# 6        Comedy    Romance      None      None      None  None  None  None
# 7     Adventure   Children      None      None      None  None  None  None
# 8        Action       None      None      None      None  None  None  None
# 9        Action  Adventure  Thriller      None      None  None  None  None
# 10       Comedy      Drama   Romance      None      None  None  None  None
# 11       Comedy     Horror      None      None      None  None  None  None
# 12    Adventure  Animation  Children      None      None  None  None  None
# 13        Drama       None      None      None      None  None  None  None
# 14       Action  Adventure   Romance      None      None  None  None  None
# 15        Crime      Drama      None      None      None  None  None  None
# 16        Drama    Romance      None      None      None  None  None  None
# 17       Comedy       None      None      None      None  None  None  None
# 18       Comedy       None      None      None      None  None  None  None
# 19       Action     Comedy     Crime     Drama  Thriller  None  None  None
# 20       Comedy      Crime  Thriller      None      None  None  None  None
# 21        Crime      Drama    Horror   Mystery  Thriller  None  None  None
# 22       Action      Crime  Thriller      None      None  None  None  None
# 23        Drama     Sci-Fi      None      None      None  None  None  None
# 24        Drama    Romance      None      None      None  None  None  None
# 25        Drama       None      None      None      None  None  None  None
# 26     Children      Drama      None      None      None  None  None  None
# 27        Drama    Romance      None      None      None  None  None  None
# 28    Adventure      Drama   Fantasy   Mystery    Sci-Fi  None  None  None
# 29        Crime      Drama      None      None      None  None  None  None
# ..          ...        ...       ...       ...       ...   ...   ...   ...
# 70       Action       None      None      None      None  None  None  None
# 71       Comedy      Drama      None      None      None  None  None  None
# 72        Drama        War      None      None      None  None  None  None
# 73        Drama    Romance      None      None      None  None  None  None
# 74       Comedy      Drama      None      None      None  None  None  None
# 75       Action     Sci-Fi  Thriller      None      None  None  None  None
# 76  Documentary       None      None      None      None  None  None  None
# 77       Action      Crime     Drama  Thriller      None  None  None  None
# 78        Drama   Thriller      None      None      None  None  None  None
# 79     Children      Drama      None      None      None  None  None  None
# 80        Crime      Drama   Romance      None      None  None  None  None
# 81       Comedy      Drama      None      None      None  None  None  None
# 82        Drama    Romance      None      None      None  None  None  None
# 83       Comedy      Drama      None      None      None  None  None  None
# 84        Drama    Romance      None      None      None  None  None  None
# 85       Action  Adventure     Drama      None      None  None  None  None
# 86     Children     Comedy      None      None      None  None  None  None
# 87       Comedy       None      None      None      None  None  None  None
# 88       Action   Thriller      None      None      None  None  None  None
# 89        Drama       None      None      None      None  None  None  None
# 90        Drama     Horror  Thriller      None      None  None  None  None
# 91       Comedy     Horror   Romance      None      None  None  None  None
# 92       Comedy      Drama   Romance      None      None  None  None  None
# 93       Action  Adventure  Thriller      None      None  None  None  None
# 94       Comedy      Drama      None      None      None  None  None  None
# 95        Crime      Drama      None      None      None  None  None  None
# 96       Action   Thriller      None      None      None  None  None  None
# 97  Documentary       None      None      None      None  None  None  None
# 98        Drama   Thriller      None      None      None  None  None  None
# 99    Adventure     Comedy     Crime   Romance      None  None  None  None
#
#        8     9  es_comedia
# 0   None  None        True
# 1   None  None       False
# 2   None  None        True
# 3   None  None        True
# 4   None  None        True
# 5   None  None       False
# 6   None  None        True
# 7   None  None       False
# 8   None  None       False
# 9   None  None       False
# 10  None  None        True
# 11  None  None        True
# 12  None  None       False
# 13  None  None       False
# 14  None  None       False
# 15  None  None       False
# 16  None  None       False
# 17  None  None        True
# 18  None  None        True
# 19  None  None        True
# 20  None  None        True
# 21  None  None       False
# 22  None  None       False
# 23  None  None       False
# 24  None  None       False
# 25  None  None       False
# 26  None  None       False
# 27  None  None       False
# 28  None  None       False
# 29  None  None       False
# ..   ...   ...         ...
# 70  None  None       False
# 71  None  None        True
# 72  None  None       False
# 73  None  None       False
# 74  None  None        True
# 75  None  None       False
# 76  None  None       False
# 77  None  None       False
# 78  None  None       False
# 79  None  None       False
# 80  None  None       False
# 81  None  None        True
# 82  None  None       False
# 83  None  None        True
# 84  None  None       False
# 85  None  None       False
# 86  None  None        True
# 87  None  None        True
# 88  None  None       False
# 89  None  None       False
# 90  None  None       False
# 91  None  None        True
# 92  None  None        True
# 93  None  None       False
# 94  None  None        True
# 95  None  None       False
# 96  None  None       False
# 97  None  None       False
# 98  None  None       False
# 99  None  None        True
#
# [100 rows x 11 columns]

# %% [markdown]
# <br><br><br> Vamos a extraer el año del título

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# un ejemplo de título: Grumpier Old Men (1995)
# confirmamos que todos los años están escritos así: (xxxx) vualá! podemos extraer los
# años usando regular expressions
# podemos hacer pruebas aquí https://regex101.com/
movies['year'] = movies['title'].str.extract('.*\((.*)\).*', expand=True)
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %% [markdown]
# <br><br><br><h1 style="font-size:2em;color:#2467C0">Parseando Timestamps</h1>

# %%
tags = pd.read_csv('movielens/tags.csv', sep=',')
tags.dtypes
# Out:
# userId        int64
# movieId       int64
# tag          object
# timestamp     int64
# dtype: object

# %%
tags.head(5)
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %% [markdown]
# Tiempo Unix o Tiempo POSIX es un sistema para la descripción de instantes de tiempo: se define como la cantidad de segundos transcurridos desde la medianoche UTC del 1 de enero de 1970, sin contar segundos intercalares. Es universalmente usado no solo en sistemas operativos tipo-Unix, sino también en muchos otros sistemas computacionales.

# %%
tags['parsed_time'] = pd.to_datetime(tags['timestamp'], unit='s')

# %%
tags['parsed_time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
tags.head(2)
# Out:
#    userId  movieId          tag   timestamp         parsed_time
# 0      18     4141  Mark Waters  1240597180 2009-04-24 18:19:40
# 1      65      208    dark hero  1368150078 2013-05-10 01:41:18

# %%
# ahora ya puedo comparar y filtrar según fechas
# entendemos que una fecha del pasado es mayor a medida que se acerca al presente, y será 
# mayor aun hacia el futuro.
print('2009-04-24 18:19:40' > '2001-04-24 18:19:40')
# Out:
# True

# %%
greater_than_t = tags['parsed_time'] > '2015-02-01'
selected_rows = tags[greater_than_t]
tags.shape, selected_rows.shape
# Out:
# ((465564, 5), (12130, 5))

# %%
#ordenamos las calificaciones en función del tiempo
tags.sort_values(by='parsed_time', ascending=True)[:10]
# Out:
#         userId  movieId              tag   timestamp         parsed_time
# 333932  100371     2788     monty python  1135429210 2005-12-24 13:00:10
# 333927  100371     1732    coen brothers  1135429236 2005-12-24 13:00:36
# 333924  100371     1206  stanley kubrick  1135429248 2005-12-24 13:00:48
# 333923  100371     1193   jack nicholson  1135429371 2005-12-24 13:02:51
# 333939  100371     5004    peter sellers  1135429399 2005-12-24 13:03:19
# 333922  100371       47   morgan freeman  1135429412 2005-12-24 13:03:32
# 333921  100371       47        brad pitt  1135429412 2005-12-24 13:03:32
# 333936  100371     4011        brad pitt  1135429431 2005-12-24 13:03:51
# 333937  100371     4011      guy ritchie  1135429431 2005-12-24 13:03:51
# 333920  100371       32     bruce willis  1135429442 2005-12-24 13:04:02

# %% [markdown]
# <br><br><br><h1 style="font-size:2em;color:#2467C0">Calificaciones promedio a lo largo del tiempo</h1>
# Hay años con mejores películas que otros?

# %%
average_rating = ratings[['movieId','rating']].groupby('movieId', as_index=False).mean()
average_rating.tail()

yearly_average = joined[['year','rating']].groupby('year', as_index=False).mean()
yearly_average[:10]
# Out:
#    year    rating
# 0  1891  3.000000
# 1  1893  3.375000
# 2  1894  3.071429
# 3  1895  3.125000
# 4  1896  3.183036
# 5  1898  3.850000
# 6  1899  3.625000
# 7  1900  3.166667
# 8  1901  5.000000
# 9  1902  3.738189

# %%
joined = movies.merge(average_rating, on='movieId', how='inner')
joined.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year    rating
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995  3.921240
# 1                   Adventure|Children|Fantasy  1995  3.211977
# 2                               Comedy|Romance  1995  3.151040
# 3                         Comedy|Drama|Romance  1995  2.861393
# 4                                       Comedy  1995  3.064592

# %%
yearly_average = joined[['year','rating']].groupby('year', as_index=False).mean()
yearly_average[:10]
# Out:
#    year    rating
# 0  1891  3.000000
# 1  1893  3.375000
# 2  1894  3.071429
# 3  1895  3.125000
# 4  1896  3.183036
# 5  1898  3.850000
# 6  1899  3.625000
# 7  1900  3.166667
# 8  1901  5.000000
# 9  1902  3.738189

# %%
yearly_average[-30:].plot(x='year', y='rating', figsize=(7,7), grid=True)
# Out:
# <AxesSubplot:xlabel='year'>
